# %% [markdown]
# # Active Sampling Example

# %%
# load matplotlib
# %matplotlib inline

# imports
import numpy as np
import scipy.stats
import scipy.optimize as optim

# import the bayesian quadrature object
from bayesian_quadrature import BQ
from gp import GaussianKernel

# seed the numpy random generator, so we always get the same randomness
np.random.seed(8706)

# %% [markdown]
# First, we need to define various parameters:

# %%
options = {
    'n_candidate': 10,
    'x_mean': 0.0,
    'x_var': 10.0,
    'candidate_thresh': 0.5,
    'kernel': GaussianKernel
}

# %%
def plot(bq):
    fig, axes = plt.subplots(1, 3)
    xmin, xmax = -10, 10

    bq.plot_gp_log_l(axes[0], f_l=f_y, xmin=xmin, xmax=xmax)
    axes[0].set_ylim(-60, 2)

    bq.plot_l(axes[1], f_l=f_y, xmin=xmin, xmax=xmax)
    axes[1].set_ylim(-0.1, 0.5)

    bq.plot_expected_variance(axes[2], xmin=xmin, xmax=xmax)

    fig.set_figwidth(16)
    fig.set_figheight(3.5)

# %% [markdown]
# Now, sample some random $x$ points and compute the $y$ points from a
# standard normal distribution.

# %%
x = np.random.uniform(-5, -5, 1)
f_y = lambda x: scipy.stats.norm.pdf(x, 0, 1)
y = f_y(x)

# %% [markdown]
# Create the bayesian quadrature object, and fit its parameters.

# %%
bq = BQ(x, y, **options)
bq.init(params_tl=(15, 2, 0), params_l=(0.2, 1.3, 0))
plot(bq)

# %%
def add(bq):
    params = ['h', 'w']

    x_a = np.sort(np.random.uniform(-10, 10, 20))
    x = bq.choose_next(x_a, n=100, params=params)
    print "x = %s" % x

    mean = bq.Z_mean()
    var = bq.Z_var()
    print "E[Z] = %s" % mean
    print "V(Z) = %s" % var

    conf = 1.96 * np.sqrt(var)
    lower = mean - conf
    upper = mean + conf
    print "Z = %.4f [%.4f, %.4f]" % (mean, lower, upper)

    bq.add_observation(x, f_y(x))
    bq.fit_hypers(params)
    plot(bq)

# %%
add(bq)
# Out:
# x = 1.4052910677
# E[Z] = 1.81816144454e-05
# V(Z) = 4.95413041126e-09
# Z = 0.0000 [-0.0001, 0.0002]

# %%
add(bq)
# Out:
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-10.] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.97997998] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.95995996] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.93993994] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.91991992] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.8998999] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.87987988] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.85985986] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.83983984] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.81981982] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.7997998] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.77977978] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.75975976] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.73973974] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.71971972] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.6996997] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.67967968] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.65965966] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.63963964] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.61961962] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.5995996] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.57957958] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.55955956] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.53953954] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.51951952] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.4994995] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.47947948] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.45945946] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.43943944] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.41941942] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.3993994] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.37937938] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.35935936] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.33933934] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.31931932] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.2992993] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.27927928] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.25925926] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.23923924] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.21921922] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.1991992] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.17917918] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.15915916] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.13913914] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.11911912] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.0990991] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.07907908] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.05905906] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.03903904] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-9.01901902] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.998999] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.97897898] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.95895896] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.93893894] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.91891892] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.8988989] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.87887888] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.85885886] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.83883884] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.81881882] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.7987988] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.77877878] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.75875876] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.73873874] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.71871872] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.6986987] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.67867868] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.65865866] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.63863864] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.61861862] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.5985986] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.57857858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.55855856] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.53853854] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.51851852] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.4984985] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.47847848] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.45845846] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.43843844] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.41841842] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.3983984] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.37837838] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.35835836] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.33833834] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.31831832] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.2982983] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.27827828] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.25825826] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.23823824] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.21821822] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.1981982] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.17817818] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.15815816] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.13813814] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.11811812] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.0980981] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.07807808] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.05805806] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.03803804] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.01801802] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-7.997998] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-7.97797798] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-7.95795796] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-7.93793794] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-7.91791792] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-7.8978979] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-7.87787788] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-7.85785786] is infinity!
# x = 7.96040833719
# E[Z] = 0.067189643101
# V(Z) = 0.0206067790608
# Z = 0.0672 [-0.2142, 0.3485]

# %%
add(bq)
# Out:
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[ 4.66225649] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[ 4.66225649] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[ 4.66225649] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[ 4.66225649] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[ 4.66225649] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-8.89749858] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-2
is infinity!
# WARNING:bayesian_quadrature:expected mean for x_a=[-1.99454488] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[ 4.77750458] is infinity!
# WARNING:bayesian_quadrature:expected mean for x_a=[ 4.77750458] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[ 5.34776549] is infinity!
# WARNING:bayesian_quadrature:expected mean for x_a=[ 5.34776549] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[ 8.26050145] is infinity!
# WARNING:bayesian_quadrature:expected mean for x_a=[ 8.26050145] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[-5.22557908] is infinity!
# WARNING:bayesian_quadrature:expected mean for x_a=[-5.22557908] is infinity!
# WARNING:bayesian_quadrature:expected squared mean for x_a=[ 7.26713339] is infinity!
# WARNING:bayesian_quadrature:expected mean for x_a=[ 7.26713339] is infinity!
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-24-8ac3b78d7cc8> in <module>()
# ----> 1 add(bq)
#
# <ipython-input-18-a8b93802cf0c> in add(bq)
#      16     print "Z = %.4f [%.4f, %.4f]" % (mean, lower, upper)
#      17
# ---> 18     bq.add_observation(x, f_y(x))
#      19     bq.fit_hypers(params)
#      20     plot(bq)
#
# /Users/jhamrick/project/bayesian-quadrature/bayesian_quadrature/bq.pyc in add_observation(self, x_a, l_a)
#     695
#     696         # reinitialize the bq object
# --> 697         self.init(self.gp_log_l.params, self.gp_l.params)
#     698
#     699     ##################################################################
#
# /Users/jhamrick/project/bayesian-quadrature/bayesian_quadrature/bq.pyc in init(self, params_tl, params_l)
#     150
#     151         # pick candidate points
# --> 152         self._choose_candidates()
#     153
#     154         # create the gaussian process over exp(log(l))
#
# /Users/jhamrick/project/bayesian-quadrature/bayesian_quadrature/bq.pyc in _choose_candidates(self)
#     979         # save the locations and compute the values
#     980         self.x_c = np.sort(xc[~np.isnan(xc)])
# --> 981         self.l_c = np.exp(self.gp_log_l.mean(self.x_c))
#     982         self.nc = self.x_c.shape[0]
#     983
#
# /Users/jhamrick/project/gaussian_processes/gp/gp.pyc in mean(self, xo)
#     595
#     596         """
# --> 597         return np.dot(self.Kxox(xo), self.inv_Kxx_y)
#     598
#     599     def cov(self, xo):
#
# /Users/jhamrick/project/gaussian_processes/gp/gp.pyc in fget(self)
#      32     def fget(self):
#      33         if fname not in self._memoized:
# ---> 34             self._memoized[fname] = f(self)
#      35         return self._memoized[fname]
#      36
#
# /Users/jhamrick/project/gaussian_processes/gp/gp.pyc in inv_Kxx_y(self)
#     331         """
#     332         inv_Kxx_y = cho_solve(
# --> 333             (self.Lxx, True), self._y,
#     334             overwrite_b=False, check_finite=True)
#     335         return inv_Kxx_y
#
# /Users/jhamrick/project/gaussian_processes/gp/gp.pyc in fget(self)
#      32     def fget(self):
#      33         if fname not in self._memoized:
# ---> 34             self._memoized[fname] = f(self)
#      35         return self._memoized[fname]
#      36
#
# /Users/jhamrick/project/gaussian_processes/gp/gp.pyc in Lxx(self)
#     292
#     293         """
# --> 294         return cholesky(self.Kxx, lower=True, overwrite_a=False, check_finite=True)
#     295
#     296     @memoprop
#
# /usr/local/Cellar/python/2.7.5/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/linalg/decomp_cholesky.pyc in cholesky(a, lower, overwrite_a, check_finite)
#      79     """
#      80     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
# ---> 81                             check_finite=check_finite)
#      82     return c
#      83
#
# /usr/local/Cellar/python/2.7.5/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/linalg/decomp_cholesky.pyc in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      28     c, info = potrf(a1, lower=lower, overwrite_a=overwrite_a, clean=clean)
#      29     if info > 0:
# ---> 30         raise LinAlgError("%d-th leading minor not positive definite" % info)
#      31     if info < 0:
#      32         raise ValueError('illegal value in %d-th argument of internal potrf'
#
# LinAlgError: 7-th leading minor not positive definite
# x = -9.08240008991
# E[Z] = 0.117360966539
# V(Z) = 1.16415321827e-10
# Z = 0.1174 [0.1173, 0.1174]

# %%
bq.gp_log_l.log_lh
# Out:
# -inf

# %%
add(bq)

# %%
add(bq)

# %%
add(bq)

# %%
add(bq)

# %%
add(bq)

# %%
add(bq)
